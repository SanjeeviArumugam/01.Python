# %%
class SubfieldsInAI():
    def list_in_AI_subfields():
        subfields = [
        "Machine Learning",
        "Neural Network",
        "Vision",
        "Robotics",
        "Speech Processing",
        "Natural Language Proecessing"
    ]
        print("Sub-fields in AI are:")
        for field in subfields:
            print(field)

# %%
SubfieldsInAI.list_in_AI_subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Network
# Vision
# Robotics
# Speech Processing
# Natural Language Proecessing

# %%
class oddEven():
    def oddEven():
        num=int(input("enter the number:"))
        if((num%2)==1):
            print(f"{num} is odd number")
        else:
            print(f"{num} is even number")

# %%
oddEven.oddEven()
# Out:
# enter the number:53563
# 53563 is odd number

# %%
class ElegiblityForMarriage():
    def eligibilty_of_marriage():
        Gender = input ("Your Gender:")
        Age = int (input("Your age:"))
        if (Gender=="Male" and Age>21):
            print("Eligible")
        elif(Gender=="Female" and Age>18):
            print("Eligible")
        else:
            print("Not Eligible")

# %%
ElegiblityForMarriage.eligibilty_of_marriage()
# Out:
# Your Gender:Male
# Your age:33
# Eligible

# %%
class FindPercent():
    def Findpercentage():
        subject1=float(input("subject1:"))
        subject2=float(input("subject2:"))
        subject3=float(input("subject3:"))
        subject4=float(input("subject4:"))
        subject5=float(input("subject5:"))
        total_mark = subject1+subject2+subject3+subject4+subject5
        percentage = (total_mark/500)*100
        print(f"Total: {total_mark}")
        print(f"percentage: {percentage}")

# %%
FindPercent.Findpercentage()
# Out:
# subject1:99
# subject2:88
# subject3:75
# subject4:99
# subject5:86
# Total: 447.0
# percentage: 89.4

# %%
class triangle():
    def triangle():
        height=float(input("height:"))
        breadth=float(input("breadth:"))
        print("Area formula: (Height*breadth)/2")
        print("Area of Triangle:",(height*breadth)/2)
        height1=float(input("height1 for perimeter:"))
        height2=float(input("height2 for perimeter:"))
        breadth=float(input("breadth for perimeter:"))
        print("Perimeter formula: height1 + height2 + Breadth")
        print("Perimeter of Triangle:", height1 + height2 + breadth)

# %%
triangle.triangle()
# Out:
# height:33
# breadth:22
# Area formula: (Height*breadth)/2
# Area of Triangle: 363.0
# height1 for perimeter:33
# height2 for perimeter:22
# breadth for perimeter:11
# Perimeter formula: height1 + height2 + Breadth
# Perimeter of Triangle: 66.0
